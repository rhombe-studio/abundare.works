# %% [markdown]
# # Pytorch->Onnx->CoreML Walkthrough
#
# Basic CNN from https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision
import torchvision.transforms as transforms

import onnx
import onnx_coreml

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

# %%
trainset = torchvision.datasets.CIFAR10(root='./data',
                                       train=True,
                                       download=True,
                                       transform=transform)

# Set batch-size to 1 for ONNX Trace
trainloader = torch.utils.data.DataLoader(trainset,
                                         batch_size=1,
                                         shuffle=True,
                                         num_workers=2)
# Out:
# Files already downloaded and verified

# %%
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()

print(images[0].shape)
# Out:
# torch.Size([3, 32, 32])

# %% [markdown]
# `dataiter.next()` returns `list(tensor(imgs...), tensor(labels...))`
#
# For ONNX export we only need the network input so it can perform a model trace.

# %%
dataiter.next()
# Out:
# [tensor([[[[ 0.0745,  0.1216,  0.1451,  ...,  0.0667,  0.0667,  0.0745],
#            [ 0.0980,  0.1373,  0.1529,  ...,  0.0353,  0.0275,  0.0353],
#            [ 0.1059,  0.1373,  0.1686,  ..., -0.0039, -0.0039,  0.0039],
#            ...,
#            [ 0.4353,  0.3961,  0.3569,  ...,  0.0118,  0.1216,  0.2549],
#            [ 0.4353,  0.3882,  0.3490,  ...,  0.1059,  0.0118,  0.3098],
#            [ 0.3647,  0.3490,  0.2941,  ...,  0.3020,  0.2157,  0.3490]],
#
#           [[ 0.1294,  0.1529,  0.1608,  ...,  0.3333,  0.3333,  0.3412],
#            [ 0.1451,  0.1608,  0.1686,  ...,  0.3020,  0.2941,  0.3020],
#            [ 0.1373,  0.1529,  0.1686,  ...,  0.2706,  0.2706,  0.2784],
#            ...,
#            [ 0.2549,  0.2078,  0.1373,  ...,  0.1608,  0.2000,  0.3725],
#            [ 0.2471,  0.1922,  0.1294,  ...,  0.1765,  0.0196,  0.3961],
#            [ 0.1686,  0.1451,  0.0667,  ...,  0.3098,  0.1765,  0.3961]],
#
#           [[-0.0118,  0.0196,  0.0353,  ...,  0.5608,  0.5529,  0.5608],
#            [ 0.0039,  0.0275,  0.0431,  ...,  0.5137,  0.5059,  0.5059],
#            [-0.0039,  0.0275,  0.0431,  ...,  0.4353,  0.4431,  0.4510],
#            ...,
#            [-0.0667, -0.1294, -0.2000,  ...,  0.4118,  0.3020,  0.3804],
#            [-0.0510, -0.1137, -0.1843,  ...,  0.3490,  0.0196,  0.3647],
#            [-0.0902, -0.1294, -0.2157,  ...,  0.3725,  0.0431,  0.3490]]]]),
#  tensor([2])]

# %% [markdown]
# ## Define a simple CNN

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ## Export to ONNX Model

# %%
this_model_name = 'e2e-test-dev-03'
onnx_model_path = this_model_name + '.onnx'

torch.onnx.export(net, dataiter.next()[0], onnx_model_path, verbose=True)
# Out:
# graph(%input.1 : Float(1, 3, 32, 32),
#       %conv1.weight : Float(6, 3, 5, 5),
#       %conv1.bias : Float(6),
#       %conv2.weight : Float(16, 6, 5, 5),
#       %conv2.bias : Float(16),
#       %fc1.weight : Float(120, 400),
#       %fc1.bias : Float(120),
#       %fc2.weight : Float(84, 120),
#       %fc2.bias : Float(84),
#       %fc3.weight : Float(10, 84),
#       %fc3.bias : Float(10)):
#   %11 : Float(1, 6, 28, 28) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[1, 1]](%input.1, %conv1.weight, %conv1.bias), scope: Net/Conv2d[conv1] # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/conv.py:340:0
#   %12 : Float(1, 6, 28, 28) = onnx::Relu(%11), scope: Net # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:913:0
#   %13 : Float(1, 6, 14, 14) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%12), scope: Net/MaxPool2d[pool] # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:487:0
#   %14 : Float(1, 16, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[5, 5], pads=[0, 0, 0, 0], strides=[1, 1]](%13, %conv2.weight, %conv2.bias), scope: Net/Conv2d[conv2] # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/modules/conv.py:340:0
#   %15 : Float(1, 16, 10, 10) = onnx::Relu(%14), scope: Net # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:913:0
#   %16 : Float(1, 16, 5, 5) = onnx::MaxPool[kernel_shape=[2, 2], pads=[0, 0, 0, 0], strides=[2, 2]](%15), scope: Net/MaxPool2d[pool] # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:487:0
#   %17 : Tensor = onnx::Constant[value=  -1  400 [ Variable[CPULongType]{2} ]](), scope: Net
#   %18 : Float(1, 400) = onnx::Reshape(%16, %17), scope: Net # <ipython-input-7-edbd921bbc5f>:14:0
#   %19 : Float(1, 120) = onnx::Gemm[alpha=1, beta=1, transB=1](%18, %fc1.weight, %fc1.bias), scope: Net/Linear[fc1] # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:1369:0
#   %20 : Float(1, 120) = onnx::Relu(%19), scope: Net # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:913:0
#   %21 : Float(1, 84) = onnx::Gemm[alpha=1, beta=1, transB=1](%20, %fc2.weight, %fc2.bias), scope: Net/Linear[fc2] # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:1369:0
#   %22 : Float(1, 84) = onnx::Relu(%21), scope: Net # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:913:0
#   %23 : Float(1, 10) = onnx::Gemm[alpha=1, beta=1, transB=1](%22, %fc3.weight, %fc3.bias), scope: Net/Linear[fc3] # /Users/rhombe/.pyenv/versions/3.6.8/lib/python3.6/site-packages/torch/nn/functional.py:1369:0
#   return (%23)

# %% [markdown]
# ## Converting to CoreML

# %%
mlmodel_path = this_model_name + '.mlmodel'

onnx_model_file = open(onnx_model_path, 'rb')
model_proto = onnx.onnx_pb.ModelProto()
model_proto.ParseFromString(onnx_model_file.read())
# Out:
# 249487

# %%
model_proto
# Out:
# ir_version: 4
# producer_name: "pytorch"
# producer_version: "1.2"
# graph {
#   node {
#     input: "input.1"
#     input: "conv1.weight"
#     input: "conv1.bias"
#     output: "11"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 5
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "11"
#     output: "12"
#     op_type: "Relu"
#   }
#   node {
#     input: "12"
#     output: "13"
#     op_type: "MaxPool"
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     input: "13"
#     input: "conv2.weight"
#     input: "conv2.bias"
#     output: "14"
#     op_type: "Conv"
#     attribute {
#       name: "dilations"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#     attribute {
#       name: "group"
#       i: 1
#       type: INT
#     }
#     attribute {
#       name: "kernel_shape"
#       ints: 5
#       ints: 5
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 1
#       ints: 1
#       type: INTS
#     }
#   }
#   node {
#     input: "14"
#     output: "15"
#     op_type: "Relu"
#   }
#   node {
#     input: "15"
#     output: "16"
#     op_type: "MaxPool"
#     attribute {
#       name: "kernel_shape"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#     attribute {
#       name: "pads"
#       ints: 0
#       ints: 0
#       ints: 0
#       ints: 0
#       type: INTS
#     }
#     attribute {
#       name: "strides"
#       ints: 2
#       ints: 2
#       type: INTS
#     }
#   }
#   node {
#     output: "17"
#     op_type: "Constant"
#     attribute {
#       name: "value"
#       t {
#         dims: 2
#         data_type: 7
#         raw_data: "\377\377\377\377\377\377\377\377\220\001\000\000\000\000\000\000"
#       }
#       type: TENSOR
#     }
#   }
#   node {
#     input: "16"
#     input: "17"
#     output: "18"
#     op_type: "Reshape"
#   }
#   node {
#     input: "18"
#     input: "fc1.weight"
#     input: "fc1.bias"
#     output: "19"
#     op_type: "Gemm"
#     attribute {
#       name: "alpha"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "beta"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "transB"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "19"
#     output: "20"
#     op_type: "Relu"
#   }
#   node {
#     input: "20"
#     input: "fc2.weight"
#     input: "fc2.bias"
#     output: "21"
#     op_type: "Gemm"
#     attribute {
#       name: "alpha"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "beta"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "transB"
#       i: 1
#       type: INT
#     }
#   }
#   node {
#     input: "21"
#     output: "22"
#     op_type: "Relu"
#   }
#   node {
#     input: "22"
#     input: "fc3.weight"
#     input: "fc3.bias"
#     output: "23"
#     op_type: "Gemm"
#     attribute {
#       name: "alpha"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "beta"
#       f: 1.0
#       type: FLOAT
#     }
#     attribute {
#       name: "transB"
#       i: 1
#       type: INT
#     }
#   }
#   name: "torch-jit-export"
#   initializer {
#     dims: 6
#     data_type: 1
#     name: "conv1.bias"
#     raw_data: "P\266\255\273\223k\322\275\310\225\002<<Y\336\275\244\007\347=P\027\253\273"
#   }
#   initializer {
#     dims: 6
#     dims: 3
#     dims: 5
#     dims: 5
#     data_type: 1
#     name: "conv1.weight"
#     raw_data: "t\355F=\017l\336\275H0N=\016(\241\275\004\r\022\275\000\306V=,a\227=\350\260W=\356 \342=\202\250\340\275\0208\317=<\022\237=\370\"\256\274\300\331\355<\321>\335\275\3225\277\275\300T\231\275\000\022\220\274W\371\353\275\2628\350\275\350\310<=\240\335\223=\260z\370\274,\006\217=$X\323\275\010\226\372<\230\022\342\2752^\242\275pvh\2744\305\341=\234I\306=\344j\323\274\260\242t\274\374\201:=\220\0201=D_\237\274\270\245\365\274 \306\325;t/\204\275\224N\215\274\000\277n=\354\371\240=q\311\222\275@rK<n\277@\275\300\003\201\275\360\240\273\274\014\0073\275\372\275\324\275\304\236\267=Zj\227\275d:\005\275jd\331=\264\316\201=\224\202\263\275\024\350\024=\2008|\273\362\"\314=\2000\362:\354\247c=\030\265\371\274Y\345q\275 \200B\273\200w\'\272\244\204M=\024\266&\275\\\302]=`\313\303=\276X\001\275,\333\243=\204\200f\275dB\333\274\310\352\312=\024\234\323=\300a4< \374y<6\234\263\2758\326\355<j\263\200=V\322\257\275p\301\022\274\3220\017\275X\004\023=\352\275\220\275\302lf\275\347\225b\275\314y[=\020\256\254<,\312 \275P\316>\275\354\304\205\274\340\357W;\350wY=6\237Y\275\030\353\323<\272\271\344=\036\236\227=\254R\\=\262O\247\275\364T\270\275b\200\201\275\220\006\235\275\266\022-\275\000R\0379\000\274\027\272\215<\316\275\000\010\364:\\|F=`\317\236\275\240~\325\274\220\224\334\273\204\353Z=\262\"\316=\354\033j=\270\026\211\2758\320\027\275\304\332\334=\200\367\337=\250\035\206\275\300\034\336:^\261\023\2750\022\311\275\264G\261=\272\024p\275\014\262\234=\354u\306\275.@\342=\324\301&=\020\373\264<@Q\";\315\227\254\275*p\205=r\267\324=\306\217\211\275Xfx=\260\0025=\n\331\277=\364\274\330\275\210\226\336=X\354\027\274\344\243\304=X\262&=\332`\323=TB%=\216=\315=\022>\250\275\300&<\273\004\223\232\275\266:\260\275\n\243\235=\314%\262\275\232|\220=h\311C\275\360\022><\262\242\274=\344\370\351\275\000\240P=\276\355\300=D\334\351=z\366\264=f\227\263\275\006%\244\275\250\266\244<j7\206=.\344\264\275\322\274\210=\350\305 =T\203\270\274\214Yc=\360\352\333;\242\227\204\275\262\352`\275*\001\302=\304x\305\274\204\302\007=p\300\226=\330\256\232\274\276n\210=8\006\354<\360\255\341=\360\2343<P\223\030=|\211f=\004\217\022=\244j\256=\020\375\372<\260\006\304\275\032J\251=\260We=8\346\366<\246\370\220=\254\241M=\350h$\275\3008\003=\\L\\=\306&n\275\274j\337\275 _\331=I\n\232\275\320\010\217;2\272\276=P\264\261;\036l:\275`\234\310;|\r\022= \372\236=\020\214\333=\356\371\254=v\345\343\275\334\037(\275\340O,\274\000Ub;\256E|\275\336\212\237\275\326\226\263\275\273\021Z\275jV\253=\240\035%=\200\237{\274\314\275\310=\322S@\275\036\201@\275\254_\236\274\372R\306=x\207\243=\346M\202\275\313\257d\275\3006\236<\236z\226=\312n\274\275\234\332\243= \020\364\273\325t^\275\026\252\230\275,J\315\2740\201\353\274\310\215\r<\264O\233\275`\316Q\274\260 C\275\217\036\220\275\224\347\013\275PD\202\275\206Q\277\275\260S\006<\010G?\274\310\211\233<\0100\037\274j\3478\275r\364\247\275\252\314\321\275x6\273<\334\263\244=\330\004u\274\003\332\327\275\364\035\250=\200\240\327=\314\202\341\275\220\327\266=\034\367<\275|R\272=\320\255\355\274XE\356\274\"<\204=l\366~=\034\2250\275\252S\244=&\370\302=h\027\273\275\334\246\343\275\354\354\325=\210\301H=\200\235\241<\310\314\234\275\314\010\307\275\304K\322=\350\273\003=\372\240\250\275F\376\335\275\177(\253\27567\271=\246u\330=\260\322\037\275g\360\330\275\360\353d=\026\324\213=\340\266\t;\370\ti=!\374\350\275\034\377\205=\370@\300<X5\276\274\214Vn=\344\351\311=^I\312\275\023\333\322\275\344\035\336=\272w\254=B\n\320=B\'\211\275\010a\275\275f\323\325=\334!\207\275Xp\300<0,\330;o\003\300\275\306V\335=\313q\303\275\2001\377;\200Q\211\274\214\317C=\322\221/\275\\\313\007\2752m\031\275\344\215\034\275\010\014\212=\352z\335=\3309\215<P\370J\274.\311\223\275lI\314\274\200\333\021:@\273\207:t\222\207=\336\242\257\275 \r\275=V^\215=V\243\024\275\300\234H=\036\353\344=H\310\221\275\324\371\004\275\271\'\305\275\324\001)=D\350+\275\200\025\360;(\025&\274\3203\234=\316\336c\275\314\262\331= \262\222\275(\370\223<\024H\243\275\000\214\201 ...
#   }
#   initializer {
#     dims: 16
#     data_type: 1
#     name: "conv2.bias"
#     raw_data: "\002i\212\275\310\250X<(4b=\200\256\327<R\215\"\275(g\227<t.Y=DH\345\274|\024V=\330\301L=\320o\242<\241su\275\375\354\201\2750\310G=\204rW=0\373\230="
#   }
#   initializer {
#     dims: 16
#     dims: 6
#     dims: 5
#     dims: 5
#     data_type: 1
#     name: "conv2.weight"
#     raw_data: "T\277\245=\3003V\273\327\211\242\275PM\204=\220\263%<\037\r\203\275p\227\237\273\345bJ\275\220m\016\274\204\025\210=\250ZL=\270\274V\274\304^D\275\010&j<\304\234w\275\r:\\\275\030QH=\326_\245\275P\345\224\274\370\333\"\275\262\'\325\274\210t_<H\034y\275D\260\266<\014\353\235=h\246R\275R\217-=@\016|<>\037\216=s\210y\275\374r\212=\226\211\274\274\212\355\226\275P+\271;h=\004=@\232\370:\222\362\364\274\256\010\003\275,\036T=J\006\214\275\000.\234<p\243\241=\267\241B\275\246Z\033=\030\323\230=h\251\240\274X\2106=</e=,\330\002=\020\202\311\273(M\231\275T\371\237<@w\314<\020\017;=\2344\222=\\\237\360\274^\223\241\275\314\341\223=\000\201}\274\300\317\256\274\210<\256<\210\301|\275l\316r=\306\344\202=\377\020l\275\000\271\240\272(\353\230\275~\300!\275\344\032\372<\246X\263\274X>\336\274\320\371Z\274\240\366\207\274.\266\037\275\3204\247\275\276N\232\275`\375\255\273\000hN=r Y\275\2452 \275\022\347)=\312\362\246=@;\234<\200\304\363\272\364*\032=\362\254)=$\240\205=\310\206A<\000\033\037\272\340PP\273\r\370\217\275\262\317\222=Wh7\275\244\277\340<;gd\275H\211\204\275\220\373\234\273 \337\302;\rv\244\275\212\372\213\275\220\311\207=D\317\r=\240\335i\274\\\'\233<,\363\222=\300\364\326;PM&<\267\271\204\275\322\206\315\2740Q\230\273\244\310\230<\203\rs\275<AJ\275\214\327Z=\010!e<T\247e=\010;\243\275wT\234\275\320\3773\275v\356\304\2744}t\275\000~:=\355\250\030\275\236\213\246\274@i9=\361\347\203\275\222vR\275,%w=\340\270\335;\2607\037=\310\254n<\210\244\346<\361\303\245\275\302\262\004=i\345\020\27586u=\3449\321\274\360\322X\274\014\237h=\212.\244=\227\2062\275\260\332\213=6\342?\275\274D*\275\034\334\034=\306b\014\275\201\"\"\275l\323\n\275\004uL=\020\267\241\275\343;i\275\320\320\214=\202)\345\274\3368\206\275\362\357\272\274\242\311$=\000\300\2078\200]\251\273\034\0145=\230\276~=@o\016\273\340\235R<4\374M=\234\314\360<>\357G\275\234<\333\2741dA\275\262\250X\275\306O\204\275\236\222\006=\2201n=\240\277\335<\264\307\210=\304\351^=7\017J\275\224#\341<>i\177\275H\266:\274$\353\222<4\365\310<d\243w\275\207\224r\275\216\354\240\275:\327\272\274\374Qd=\242\354\214=(\216\020\274\300\363t;\220=n\274\215\202D\275\222\243\024=\220\341\200\275\2201X\274\344@l=\262\273\223\275p*x\275\"O\230=\030\323\203\274\340v\t=Tl\027\275\2745\240=\360\351\200\274\253\352#\275@\260\235\275gz\222\275\345\351F\275L\304w=\002\306\212=\200lP\274?\316\231\275D\370U=`\2721\275p\302/=~\311\022\275\340*o=\212\237\025\275\227\332\006\275%r=\275\220\246\216<\332\021\217=\024\013\303\274\210\005\334\274\200\245\373::\203\026=vX\002=\360\033\252\273\030\371\346\274\330zi=\020\304\365\273\030NJ\275\006T\231=2ak\275\255\275\221\275\340Q\331<\364\'\227=Pa}=\354\374x\275\314\356\240\275d\\q\275\340\264\013=(\227\377<@\250\024\273\240\216\316\274\010+\225\274\276X\313\274\030\317Y\275\313v\030\275\250~\332< \036p=\237\301\220\275\304\217\213=\376\273!=\250\271;<\n\300\243\275\n\014\212\275\310\257\033\275\320\353\340\273`\207\301<\214\215\014=\010\306\226=<\340\267\274\022\236+\275\206\035\244=\336I\366\274H4@\274 \311U\275\276\271k\275\032\3754\275\360;\262;t\036\214\275\n)\r=\002v\203=\026\'\017=X1\\<,F\273<\0005 :<\334\232=6\363\334\274v\376T\275@ar\274\000\230u\273\250A\\\274( [=pL\265\273\206\335\216=\002\274\357\274\204\271Z=\230\300\357<\320\233\276\273\310\021\265<-\357\207\275\\q\371<\324t6=:\224\230\275\010 &<\330cG\274|\210\213=\310B,\274\340\343\302<\252L\036=\366\341\207\275\240\307\342\2744\241j\275\354^y=\300:\205\273\260\365U\274\210\033W=\020\024\275\273\022\264\332\274\024\236\222=Zb\343\2748\354Y=2:\215=a\365\216\275\360\344\253;\252\245\242\275X\223{\274\330@\337<in\226\275\0305^\275\320+Z=\362V\"=\004\326[=\350!\016<\010\364\244\275\250\215r=x\354j=b2\243=\016\004\031=.\352{\275\232\333.\275\334\321m=\220Y\352\273\346\020\300\274\306\034!=\330\213)=\354\212\226\274\306\360\214=\210I\024\274\366\026\026\275\340jS=W\302)\275\2144\211\275\240\352B=@\t1\273V\010\340\274yQ\035\275\340\204G<\340\325G\273x\010\205\275\322F\220=x\266\035=\233\321\211\ ...
#   }
#   initializer {
#     dims: 120
#     data_type: 1
#     name: "fc1.bias"
#     raw_data: "\220\225\035\275\000W\237\272 H\226\274( \020\274]\347\"=H\236>\274\224p,\274\000\333M\274\303wE\275O\257>\275r\t\376<\250\300r\274\350\247\261\273P\201\375\274\000\332\345\273c\271\016=@\377\355\272c\312\366\274dp{<{\345\007=$\275Z<M\035\007\275\327\002\307\274\220\246\306\273\371\033C=M\031\354\274\347\"1\275\010C\032\275{\342A=@\025\331:\255(*=}\332$=~9(\275<\217v<\335u\301\274\247\277\367\274 \246\270\274\316B\255<|\006\013\275w\261\022=0L\370;\345\007I=v8\032\275z\334\215\274\275\2121=\250W\t<\317\r2=J\316\017\275\310\267<<4\\X\274\0229.\2750\373\346\274\327\0246\275\253gA=\242@\216<\r\224\335\274\313\225B\275\220\352\241\2735UF\2750\376\325\273{\2411=\262\021\272<v5\252<\361\276>=\302\227\013\275\204\275f<\032\367\233<\242C\213<\375\014\244\274\2766\004\275@\210\235\272\261jI=\303;\354\274\343P\326\274(\214D\274\247\323\n=\331~1=\320ie\273\300\323\240\273\254\216~\274\364,Q\274\312\330\316\2746h\267<)5\020=\022\323\207<\000i3\274\203V@\275@\037\020\274@\352\304;hW\'<\320\222O\273\370\235r\274\265\017J\275\014\263k<P\361\374\274\320\225m;1\317D=Ui?=\301\245\007=\rt\006\275\201\351\002=\021I\037=\345\255\033\275\330?\322;-B\305\274\300Y\210;\rm2\275.\231\026\275\004\270\014\275\271}/=\3523\251<t\267+\274\375\331\375\274`\372#\275\260\016N\273\000\226\254\274TGG<6\023\264<\337\3030\275\275\221\246\274"
#   }
#   initializer {
#     dims: 120
#     dims: 400
#     data_type: 1
#     name: "fc1.weight"
#     raw_data: "\20522=v*\022\275\220\260\221\273]\3720\275g[\261\274,\007\032<\233\342\037=\360\373\310\273\030f\r<\242\206\016\275\261S\031=\373\250-\275`\360\014\275\244\222^<h\371\031\274\177\376\025=\320i\270\273\32074\275\363\262\010=\372\020\373<\240\315\035\274\036\234\342<\311]\003=\304\376T<V\333\n\2750\323\320\273\030\362\304;\014\263\027\274\305>#\275\307\215\322\274j\302\236<\024Qn\274\260\231j\273\215D\004=\351\000\r=\300D*\275\001\215\021=w{\007=\252\017\226<\220R\224\273\203C\364\274\302\334\251<j\307\370\274]E?\275\271\243D=2\217\207<\177\272+=B\027\343<\3070\374\274(l\344;\364\311N<5\2007=l\025\216\274\272\206\275<\330x\254;\222\244\330<`-C\273h\217\306\273\205\1777\275\205\223==]\314#\275m\221!=`\177\t;\300\364\360\273,j\002\275V\177\316<Y\025\002=C0\272\274\342\230\345<\007\276\341\274\330\362\222;\215;\261\274\326\256\377<\024\272J\274\022\257\300<\267\026\013=7}\263\274\032a\262<\240Of\273\320\354\022\275\000\236\202;@h\360\273R8\366<\367o\036=^o\200<`/\322\272]\251\037=(V\271;\212\301\345<1\3636=r\320J\275?\037E=\320\344\264\273\311\310==J\334K\275\320\\E\275\032\014\356\274@\241\217:\212\017\241<\273\336\034=\036\353\321<\314\235F<\023\3147\275\023u)=\321\203;=hr\010\274\320\363\201\274\357\014J=\313\200\010=\237\306I\275\004ee<\n\245\354<\242i\300<\306\006\035\275\352\377\301<\372<5\275\326\363\370<\370\035<\274\032\272\371<\027t\376\274\245\2600\275\2322\333<r\006\344<\301\271$=\370\206<\275\3471\267\274z\230\267\274\002\200\320<:\034\026\275A!\037=\024C\032<PB\230\274Y\177\017=\354\026`<\240\255\003;$\274{<\214\243\037\274\033\347D=Dio<\300\206\376;`S\323\272Z,\300\274\247DH\275\312\220\322<t\335a<\224\nl<\355\2510=9\374\013=d\272f<\346\215\362<\300\336\r<4\2010\274\026a\200\274\372\264\250<=\233\035=\255\3332\275xk7\274\345\026\017=\002\033:\275\276\303\261<\300\203\342\274\214A\006\275\314\222\005\274ng\'\275\200\034r;\014\246k<\007\260\005=\030\266\021<\r\2622\275d\250Q<P\346\006\273uF*\275\270\036>\275#\025\356\274\020\376\021\275W\tH\275P\340\307;\320#\025;\025q\014=2\323\247<J\003\342< -l\273S@\337\2748.(\274j\355\371<\254db<@\363\021:\322\'\256<f\201\272<\2603i;\030\331H\275\300pj\274Q\2024=\236\367\355<\364\237*<\215J\361\274\004]U<\000\345\030;A1\026=\360\217\244;X\317\335\273X\"J<\330\2157<\223\263\334\274\n<\210\274c\313\"\275Oq\033=\200\016B\273\272dF\275\325\246\025=\205r=\275\000(9\273\351\000\"=\214\032,<\027$5=\330\232\321;\037)\006=0\267\324;z\220\241\274\340bd;\000\tz;\362P9\275\300\t\354;\240\230C;\025\363\032\2758\000-\275\264\344h\274#\261\001=LFf\274,)\006<\000k\2609\240\020\031\273`\010s;\'\356\037=\027\371\266\2748\356]\274\213\304*=b>\203<`\217\336\272\322\305\340<\324\235\222\274\025\310\037\275l]S<\302U\313<H\006_\274\362\003\264<\000\325<9`\336*\274\302\326\226<\013\2052=\260h\354\274\214\237_<\001q\r=p\275\241\274\000H 9\033b5=v\026\313<\255\271\340\274\003a\250\274\003\300\376\274\326\254\343<\305\314%=G#\344\2744\261\032\274V\333\227\274\010\320\034\275\010H$<b\215\211<O\014(=\260s0\273j\241\272<P\364:;r-\260<\241GA= 8\037\273\032T\267<r\231\235<\263\351\357\274\232x\010\275@X\265:@\273\205\274\372\245&\275pH\364\274\202\333\256<\336\227\234<\267\003\013=\350\377\306\273\320\254\342;\335\206\312\274X\346\273;)\304\017=\230\336\353\273\305\036\001\275N%\365<b\247\266<F\240\037\275!a8=\204\243a<_\271\005=6\262\316<\n&\302<\223\377\353\274J\337\207\274\250{\250;\027_\261\274f\276\333<\230\207%<{X\027\275a\030\007=\225\226\013\275\372b\242\274\033\366@=\200\246x:\320\223\240\274@\240Z\274\221k\017=#9\244\274@b\271;P\341%\273\202\006\021\275\230\263\020\275\230\313w\274\342$\322<J\020\261\274ZR\375<\0003\261\271\303K\026\275\002\204\263<\035t\370\274\031j/=1\2709=\000\332X;\230f\377\273\344\277\177<)\0142=\030\271]\274\300.T\272[K&\275Y`,=\353\345>\275!\263\033=\260\022\002;\211\344,=T\332c\2746\021\225\274\024\310)<\301\235\014=\272m\014\275 y\014\274X\363C\275JAK\275\215\246\017=\204\025\204\274L\251h<\362$\227<\350gF<F\246\037\275\250\277d\274P@\306\273\372\343\311\274\200 ...
#   }
#   initializer {
#     dims: 84
#     data_type: 1
#     name: "fc2.bias"
#     raw_data: "hk\357\274\334\316\231\274\020/a\274\330\300\237=xI\'\274\304\273\251=#\035\262\275x\3138\275`\\\272\275\252+\266\275\310E5=\207d)\275@\360\206<`\242X;\3765\241=\222\261\265\275<\356m=U\2059\2750\004\344\274 \222\306<\250\242\247=\300\336\024\275@p\243\272P\014V=\364\206\334\274\200 \372\272D\207$=\232\223\215\275\220 \245\275@i\361\272\266s\223\275\220J\210\274\210\020V=0.\231=\034\305Q=\010\032\202= \021\236\273\364;>\275\350\234k\275h\3768\274\020\224$\275\320\366\225<q\036A\275\246C5\275\016\255\253=\310\314}=\222\354\002\275>\347\224\2752\374\261=\264\225\325<\354\261\301<\t\320q\275d\304%\275\244T^=\230ja=*\336\226=\177\2279\275\200K\247\272F\005W\275d\313\211=@\022\033=\304\271l=\330\351}=\2401\226=m\0323\275\235\n\252\275uM\"\275\032W\236=X\022v\275T\270\013=\334\324 =P\235R\274d\261\n=<wG=L\264O=0kz=\200\272i;\\\321\225\275\2104x=\334\357\344\274\374*\200\274|&\002=\234\223\225\275R\336\210\275"
#   }
#   initializer {
#     dims: 84
#     dims: 120
#     data_type: 1
#     name: "fc2.weight"
#     raw_data: "\216Z\205\275\326\373\360\274\264\253N=\256R\202\275\364\205\215=\210\332\213=,\347e=\347\237\006\275\272\0136\275}]4\275\362\354\257=\000\334V\271\030At\274\340\031f=\205\'.\275h\253\220\2752\230\231\2759\375\003\275\3445,=\022p\224=\244\ra=\324#*= \301\010;l4\213<l_\314\274DP\272=0\215\225=$\212E\2757U]\275\311BS\275#\216\214\275@\361\317<:\206\225=\213<V\275\034i\250<\034\260%=lr-=\314\205\232\275\024\016\r=\200p\006\275\344\201\251\274\344lf=\tg\014\275\260S\200;\215\224?\275\014\227\n=7\334g\275\254H\020=\200\004\274;\200u\264\275\200\340\345:\2125w\275\234\317\204\274\360~\333\273L\371\377\274\330\302\354<u<_\275g2\206\275u|\005\275!\357\265\275\300s\216:\'&\230\275\234\0355=\312H\217=9\330\020\275\260\\\217;?w\214\275\014\215\235=(\216\227\275\332e\203=\224\365\322<P\030i=`\014\241=\334\233\203\275,\035\244\275\005/`\275X\254\265\275\270\255\024=\214\227\230=wW\251\275\307;\221\275@\331\335;`\333\230;\302\260\230=\206}5\275@i/;\360\221*\275\240\320\033\273\022&\000=\312h\232=\271;o\275!\357\214\275\246\214\233\275\220i\214<\364<\350< \353\213\273\020x\273;\373\376 \275\350*\240=\034\307\307<\200\341\327:\034\267\251=}\257\242\275Pb\221\274z(\230\275\211\332\256\2753:\016\275V\211\246\275\300\220\251:@c\204<\274k\336<\234`4=\372\370\210=\300\206\323;\220Rx<\000@m<\246\332\270=L]\216\275D]#\275\330tP<\022Q\242=\340\216\253;\000\335\226;|bh=\014\030n= wY=\320\251~\2740g#=0:1<\020\2543\274\311\220\242\275\324\213\353\274Tb\000=\220\363\324;h\313\r=\206W\213=\311SV\275F\207\241=0\372\024=@*-\274x\034=<\240\n\267=\000\017\214;\246\303\215=T\001\225=\024\003\306<\200l\320:H\231\n<\016`\036\275\001o\271\275\000\317\341\274\374\343\260\275d\031I=\030}\351<P\023\245\274q\367n\275\262\346\226=|\035`=\334\\\262=\335\337\\\275\274\000h=\254\256\227\274\270:q<\020\346V\275\3574\261\275\202\"\232=:\270\375\274XB\216<x\335\237=\331Hw\275\340\201K\273\302\210\202=,v\313\274\244\343\022=\250\274\'=$\226a\275\323\307\036\275h\022a< \300.=\340K0=\240\314\306;\302y\007\275\000\334\201=\302b\205=\344D\350<\3200_<\340\236q\273<7$=\223\010\000\275t\372\226=\000\177\273\272f\255\202\275\300x\360:\224\3039=\340\016\'\274\205\237O\275L_\225<(\203x\274<\222\251\274\210\214\014<\330\226\351<_4\250\275T\302\240<z7\264=,\235.=\220]\022=($\216\275\270\232g=\372\204\226\275+\017\266\275\220\036\256\275\246c\225\275,\3544\275\004s9=\350\251o\275F\215G\275,\224G=\225\033\210\275@4\277:\033\326c\275\200Q\202\272L\246\223\275p\307\217\274\376\205\013\275\000\226\263<\200\205\026\273\240\270@<\352s\232\275\324b0\275\240]{=xIH=\274\3451=0$\354<h\306+\275\300\027\003=\246\365\225=\344\277\220\2744\321\351\274(iE=\310\373o=h\360g=\030&D<\254h\267\275\374\362N=\260\217l=\367V\237\275p\206\312<\204\037^\275;D\260\275\3207\200;\204y\262<\264\355\340<\300\342%\274\0362\227= bC<\034\025#=\2108\016<\236<\253=\334\316\216\274\210\243\024\274\324^\345\274\024\224\305<\010j1<\245\035s\275\370\222m=\240\214\035;Z5\223=C\307x\275\222\244\201\2750\024C=\360\022\024=\240\357\207\275\330\"R<L\346r=n\374\010=z\004\\\275\257\227\227\275\370\305\267\274 \274\235=Tq\301<`\207\330\273Lz\266\274\246\034\001=hc\212\274uH0\275\313\3572\275z\355\224=\260\350H\274\262\317n\275\243\254\"\275\320\030\303<\362\307\230=\362w\232=\340\004\203=\240L\211=\340l\261=\211\324\230\275\025\242\006\275V\261\362\2740\371\200;\320\253%\274\204_\036=\340\006\206\274`\2450<\226\225\205\275\032k\254=\246I\242=\232\347\223=z<\201=\234\310\205\274\264J\002=\370\3364\274\240\037\256\275\220\021\361<&\350N\275\340\273!\275\254\327\260=\254\232\252=@\365\270:,\270\r\275\300S\371;$\324 =P\341L<\224\225\255<\210\315J=wQJ\275\230Q\341\274\326\262\214=\215\223\252\275(\365N<\300\034\320\274\220\364\313<$\324\255\275u\355a\275p\327\266;h\327\034\274\321}\006\275\224C\022\275Xj\253\274\350\235\347<\354\274\316\274\374\000\341\274\314\341*=\372\272\251\2758d\324<\021\355\001\275E\224\266\275@tB;\271\2221\275\022/\221\275\025\274\261\275\220\340K<\254\305\307\274p\205\\\274\220\340\243<\314\311\202\ ...
#   }
#   initializer {
#     dims: 10
#     data_type: 1
#     name: "fc3.bias"
#     raw_data: "Y\330\336=\264\362$\275.\351\226\275\022\013g=\305O\303\275\200\027\354\273\231\251Y\275\234\021\277<\322+P=:\312e="
#   }
#   initializer {
#     dims: 10
#     dims: 84
#     data_type: 1
#     name: "fc3.weight"
#     raw_data: "yA\256=\330\351\234\275\234\232\264<\244\260\235\274@\234\367\273D\366\242\274Y\205\234\275\344-\303\275\336|\031=\000l\006\271\300\004\202<\025\331\306= \277\016\275\000\205G;\246]\007=\331,\253=\242i\020\275\205JQ\275H\231\326\275Xy\331\275\014\311\256<n\252\334\275\2275\210=\014\267\274\275\220\245M<\216\261\'=fQ\023=\217\304\327=\273\262\247=\225\243\332=\361[\262=WS\215\275\312Y9\275\312J\220\275A\'\265=\332k\024\275+\023\300=R)b=\0000\3117Vb\254\275FR\233\275Dp\260<\314\326\253<\317\247\231=\005\007\330=\220:\224\273\0373\272\275y\360\247=V\025\020=\326\351+=\337\001\301\275\362\032\204\275\033\214\232=Lv\322\275\020\261B<\252b\025=\237`\200=\021d\312=;\345\220\275\207\211\314\275\254\234\231\275\340\013\302\273t&\340<\240\010\206\275jH>\275\220\n\243\274\356SV\275\357\223\237=\256P\\\275\262@M=x\343\223\274\333\337\315\275\274\322\237<\245\030V\275R;\014=\206\221\010=(\373\344\2742\0340=f\3129=\226\262z=\350zT\274pw\324\274\254\037\216\275\r\367\241\275\242\030L=s$\243\275\250hj<\360O.\274\004c\244\274Md\314\275\370D\263\275\003\036\271\275\374!\275<\r\240\201=Z\224=\275\237[\335\275\200\334k<-\270\212=\005\365\277=\004&\247\274\252\026\t=k{j\275\356\267\003=\2256\307=$\217\274\274 \330\246\275d\212\204<\272\315\301\275A\207\222\275\372\025\304\275\235\214\207\275\314\250\265\275\352\371\000=\374\263S\275\324I\234\275\266\2422=gJ\331=\266\370p\275\3008\360\274``\271\275\364\262\321<4\t\343<\016yc=\020G\207\273\250\360A\274\236\261(=\3317\245=\365\363\255=\311\225\326\2750jy<|\324\246\274\020\337\332;\224\213\323\2744:\316<\344\214\236\274\274\030\333\275\375H\274=\274\216\320<c\271\211=j\210\247\275\354\305\343\274\264\351\256\275x\232\236\275\270\251\276\274\267-\262=\222N\221\275\366[.=(zy<q\264\246=\344\221\256\275\353\366\316=HT\235\275\001\r\331=\\\'\206<\032\n==\266\225\336\275\000\0224<`\310>\274`Ga\274\020\034\357;\\y\240\275L\034\361<\260/\311;\254M\204\275\200_/<\332Pw=\214\014\205\274\266#\307\275Y_\263=\026\334l=t\235\322\2753^R\275\020Sa\274\237\270\323\275\341\003\314=?\256\326=#\246\274\275jUh=\004\224\036\275\230\ny\274\357 \317=\316\334/=\266\321P=\202\005\007\275N\033\"=0P\301;V\252w\275\000\36699\002\nv=X\356;\274nES=Dj\277<\344\236!\275(,m\275\311w\323=\276\"\203\275\234\245\221<B\360\201\275\214\221=\275\342I!=go\215\275\305G\242=\3407\201\2751\014\230=4\034\346<\306Ws=8~\221\274\322LY=\013l\212= |\203;!\274\216=\202G\304\275NI\004\275\337\240\274\275\033\210\315\275\3707\020<\200\357\371\274R\204\250\275X!\326\275Z\336s\275\234w\317\2755/\275=0\313y\274\nqC=b=\016=\201i\221=\252\375\026=#^\222=$\350\213<#\276\264\275\000,]\274\253!\315=\253\207\316=\304%\262\274\231\006\213=\334`}\275\366\177T=\016\240\216\275\210\303\357\274\314\354\364\274R\265\013=\3352\225=a\343\265=\032\005\235\275\216\224\216\275\304\215\365<\206~*\275.\230\244\275\352\313R=MS\237=\324\001\006\275\272\034\023\275\375%\300\275\334\3148\275\266\354r=\361\001\201=\254^\036\275\363\240\323\275(\000>\275\222\251C\275\0103u\275+2\257=\\N\320<\024|\252<\nSJ\275\35642=\264\177\210\275F\364\207\275\0070\330\275hT7<\300\n>\273\306TI\275C\376\256=@i\257:\224\212\322<rG@=\010F\305\2740\207\247\274\005\220d\275L\367\365\274\345\202\303=tp\236\274\212(V=QD\306\275f\337\253\275\203\315G\275$L\337\275\350y\245\274H\3205<\300\322\231;;\364\271=\257\006\262=\371\322\320=q\r\232=X}\253\275\216\'\221\275~%\003\275\200\355Z\272\331\306\244=\036(\304\275\200\234{\272\254r\265\275aOL\275Un\271=\241\350\224=\266bA=\000\217j;\003\220j\275>\013\016\275Z\306m=\216=g=\374\t\212<\022\003\275\275\002R\207\275\000\264\t\275v\330-=\216\306,=\006\rG=X3\317\275(\351V<\360.8\275ce\316\275\376\244D==\242z\275&\333\305\275\237y\253=\350!X\274X\241\366\274\036\260z=\202\370\032\275\353\271\240\275\340\371\232\274\010\342<\274\255\266\254\2750\353i<@J\304\275\264d(\275\030\021\030\275\320\214\207;\000A\272\272\316\037\213\275\334\253\210<\344%5\275HoY\275\354\342\353\274\r\211\260=\000\034\302\270&\206\222\275\344,\023\275C,\250\275\007\344\210\275\ ...
#   }
#   input {
#     name: "input.1"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 32
#           }
#           dim {
#             dim_value: 32
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "conv1.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 3
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 5
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "conv1.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 6
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "conv2.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#           dim {
#             dim_value: 6
#           }
#           dim {
#             dim_value: 5
#           }
#           dim {
#             dim_value: 5
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "conv2.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 16
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "fc1.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 120
#           }
#           dim {
#             dim_value: 400
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "fc1.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 120
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "fc2.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 84
#           }
#           dim {
#             dim_value: 120
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "fc2.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 84
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "fc3.weight"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 10
#           }
#           dim {
#             dim_value: 84
#           }
#         }
#       }
#     }
#   }
#   input {
#     name: "fc3.bias"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 10
#           }
#         }
#       }
#     }
#   }
#   output {
#     name: "23"
#     type {
#       tensor_type {
#         elem_type: 1
#         shape {
#           dim {
#             dim_value: 1
#           }
#           dim {
#             dim_value: 10
#           }
#         }
#       }
#     }
#   }
# }
# opset_import {
#   version: 9
# }

# %%
coreml_model = onnx_coreml.convert(model_proto,
                                   image_input_names=['inputImage'],
                                   image_output_names=['outputImage'],
                                   disable_coreml_rank5_mapping=True
                                  )
coreml_model.save(mlmodel_path)
# Out:
# _make_coreml_input_features
# Collected input_features:  [('input.1', Array({1,3,32,32}))]
# 1/12: Converting Node Type Conv
# 2/12: Converting Node Type Relu
# 3/12: Converting Node Type MaxPool
# 4/12: Converting Node Type Conv
# 5/12: Converting Node Type Relu
# 6/12: Converting Node Type MaxPool
# 7/12: Converting Node Type Reshape
# 8/12: Converting Node Type Gemm
# 9/12: Converting Node Type Relu
# 10/12: Converting Node Type Gemm
# 11/12: Converting Node Type Relu
# 12/12: Converting Node Type Gemm
# Translation to CoreML spec completed. Now compiling the CoreML model.
# Inputs:
#   input.1 [1, 3, 32, 32]
# Outputs:
#   23 [1, 10]
#
#
# def model(input.1) :
# 	11 =  convolution (input.1)
# 	12 =  activation (11)
# 	13 =  pooling (12)
# 	14 =  convolution (13)
# 	15 =  activation (14)
# 	16 =  pooling (15)
# 	18 =  reshapeStatic (16)
# 	19 =  batchedMatmul (18)
# 	20 =  activation (19)
# 	21 =  batchedMatmul (20)
# 	22 =  activation (21)
# 	23 =  batchedMatmul (22)
#
# 	return 23
# Model Compilation done.

# %%
res = net(dataiter.next()[0])

# %%
res.shape
# Out:
# torch.Size([1, 10])

# %%
coreml_model
# Out:
# input {
#   name: "input.1"
#   type {
#     multiArrayType {
#       shape: 1
#       shape: 3
#       shape: 32
#       shape: 32
#       dataType: FLOAT32
#     }
#   }
# }
# output {
#   name: "23"
#   type {
#     multiArrayType {
#       shape: 1
#       shape: 10
#       dataType: FLOAT32
#     }
#   }
# }

# %%
import coremltools

coreml_model.predict({'input.1': dataiter.next()[0].numpy()})
# Out:
# {'23': array([[ 0.03159744, -0.10788564, -0.09554024,  0.04849986,  0.060378  ,
#           0.10113253,  0.14130479,  0.11806699, -0.00622333,  0.04473902]],
#        dtype=float32)}
